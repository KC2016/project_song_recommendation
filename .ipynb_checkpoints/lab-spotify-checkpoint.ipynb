# %% [markdown]
# # API Wrapper - Lecture activities

# %% [markdown]
# ## Activity 1

# %% [markdown]
# - create a list and assign it to a variable named `my_20_artists`.
# - loop over your 20 favorite artists and their results to the list.
# - create a function that takes a list of artist names and return thei 50 first appearences as a dictionary.
#
# https://www.notion.so/Berlin-data-classroom-5f8f3ff27075492b8b457677368fda2d?p=28b25b8f0466486ebbecc7380c15b7d0

# %%
'''import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id="your client id goes here",
                                                          client_secret="your client secret goes here"))'''
# Out:
# 'import spotipy\nfrom spotipy.oauth2 import SpotifyClientCredentials\nsp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id="your client id goes here",\n                                                          client_secret="your client secret goes here"))'

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import getpass

# %%
client_id=getpass.getpass('client-id?')
# Out:
# client-id?········

# %%
client_secret=getpass.getpass('client-secret')
# Out:
# client-secret········

# %%
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=client_id,
                                                          client_secret=client_secret))

sp

# %%
results = sp.search(q="Lady Gaga", limit=50)
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# <ipython-input-8-a01e51d58981> in <module>
# ----> 1 results = sp.search(q="Lady Gaga", limit=50)
#
# ~/opt/anaconda3/envs/ironhackenv/lib/python3.8/site-packages/spotipy/client.py in search(self, q, limit, offset, type, market)
#     545                            from_token.
#     546         """
# --> 547         return self._get(
#     548             "search", q=q, limit=limit, offset=offset, type=type, market=market
#     549         )
#
# ~/opt/anaconda3/envs/ironhackenv/lib/python3.8/site-packages/spotipy/client.py in _get(self, url, args, payload, **kwargs)
#     289             kwargs.update(args)
#     290
# --> 291         return self._internal_call("GET", url, payload, kwargs)
#     292
#     293     def _post(self, url, args=None, payload=None, **kwargs):
#
# ...

# %%
artists =['Madonna', 
          'Queen', 
          'George Michael', 
          'Ivete Sangalo', 
          'Lady Gaga', 
          'Scorpions', 
          'Lulu Santos', 
          'Adele',
          'Marisa Monte',
          'Emilie Sande']

# %%
# CHECK AND FIND THE PROBLEM
my_10_artists=[]

type(my_10_artists)
# Out:
# list

# %%
# # my solution
# for i in artists:
#     a= sp.search(q=i, limit=50)
#     my_10_artists.append(a)
    
my_10_artists
# Out:
# []

# %%
my_10_artists = [sp.search(q=artist, limit=50) for artist in artists]

# my_10_artists=[]
# for i in artists:
#     my_10_artists = my_10_artists.append(sp.search(q=i, limit=50))
    
my_10_artists
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# <ipython-input-13-2fdfde9eb827> in <module>
# ----> 1 my_10_artists = [sp.search(q=artist, limit=50) for artist in artists]
#       2
#       3 # my_10_artists=[]
#       4 # for i in artists:
#       5 #     my_10_artists = my_10_artists.append(sp.search(q=i, limit=50))
#
# <ipython-input-13-2fdfde9eb827> in <listcomp>(.0)
# ----> 1 my_10_artists = [sp.search(q=artist, limit=50) for artist in artists]
#       2
#       3 # my_10_artists=[]
#       4 # for i in artists:
#       5 #     my_10_artists = my_10_artists.append(sp.search(q=i, limit=50))
#
# ~/opt/anaconda3/envs/ironhackenv/lib/python3.8/site-packages/spotipy/client.py in search(self, q, limit, offset, type, market)
#     545                            from_token.
#     546         """
# --> 547         return self._get(
# ...

# %%
# create a dictionary
def artists_to_dict(artists):
    return {artist:sp.search(q=artist, limit=50) for artist in artists}
len(artists_to_dict(artists))

# %%
{str(key):key**2 for key in range(10)}

# %%
dct = {}
for key in range(10):
    dct[str(key)]=key**2
    
dct

# %% [markdown]
# ### Lecture: For Lady Gaga only

# %%
results = sp.search(q="Lady Gaga", limit=50)
results

# %%
# check the type
type(results)

# %%
results.keys()

# %%
results['tracks']['href']

# %%
results['tracks']['limit']

# %%
results['tracks']['next']

# %%
results['tracks']['offset']

# %%
results['tracks']['total']

# %% [markdown]
# ### Explore the items

# %%
len(results['tracks']['items'])

# %%
# for the first song:
results['tracks']['items'][0].keys()

# %%
results['tracks']['items'][0]['album']

# %%
results['tracks']['items'][0]['album'].keys()

# %%
results['tracks']['items'][0]['album']['artists']

# %%
results['tracks']['items'][0]['album']['id']

# %%
results['tracks']['items'][0]['album']['name']

# %%
results['tracks']['items'][0]['album']['release_date']   # yyyy-mm-dd format

# %%
results['tracks']['items'][0]['album']['total_tracks']  # songs of the album

# %% [markdown]
# # more info of the first song

# %%
results['tracks']['items'][0]['artists'] # track artists

# %%
results['tracks']['items'][0]['id']

# %%
results['tracks']['items'][0]['name']

# %%
results['tracks']['items'][0]['popularity']  # popularity index

# %%
results['tracks']['items'][0]['uri']  # basically ID

# %% [markdown]
# # Activity 2
#
# Create two functions: One to extract all the **artists** of a song and another function to extract all the **artists IDs** from a song.
#
# - Input: Dictionary of one track, e.g. results["tracks"]["items"][0] for the first search result.
#
# - Output: List of artists/List of IDs of that track

# %%
# my_track=results['tracks']['items'][0]

my_track=

# %%
my_track['artists']

# %%
def get_artists_from_track(track):
    return [artist['name'] for artist in track['artists']]

def get_artists_ids_from_track(track):
    return [artist['id'] for artist in track['artists']]

# %%
get_artists_ids_from_track(results['tracks']['items'][0])

# %% [markdown]
# ## Playlists

# %% [markdown]
# **Categories** -> get all the **playlists** (IDs) in that category -> get all the **songs** (IDs) from all playlists (together with their audio feature) -> get all the audio features with these IDs

# %% [markdown]
# Playlist link:
# https://open.spotify.com/playlist/75GeX247deNdTX7zdyZDnU?si=29f55c0ba7d84da0
#
# From that this is the ID: **75GeX247deNdTX7zdyZDnU**

# %%
playlist = sp.user_playlist_tracks("patrickimoh", "75GeX247deNdTX7zdyZDnU")

# %%
len(playlist['items'])

# %% [markdown]
# Overall goal of this part of gnod is **a dataframe** like this
#
# artist | title | id | accousticness | dancability | ... | ...
# --- | --- | --- | --- | --- | --- | ---
#  |  |  |  |  |  |

# %% [markdown]
# **Target: Get all the ID's for all the songs in that playlist!**

# %%
# let's get the ID for only one song first!
playlist['items'][0]['track']['id']

# here i make it work for the whole playlist
for item in playlist['items']:
    print(item['track']['id'])

nigeriantop100 = []
for item in playlist['items']:
    nigeriantop100.append(item['track']['id'])

# %%
nigeriantop100

# %%
# these are the audio features for all songs in the playlist
sp.audio_features(tracks=nigeriantop100)

# %%
audio_features_nigeria = pd.DataFrame(sp.audio_features(tracks=nigeriantop100))

# %%
audio_features_nigeria.head()

# %%
ls

# %%
from IPython.display import display, Image
display(Image(filename='gnod_1st_prototype.jpg'))

# %%
from IPython.display import display, Image
display(Image(filename='gnod_2nd_prototype.jpg'))

# %% [markdown]
# ### How to get the spotify categories

# %%
# get all the id's for all the categories
[item['id'] for item in sp.categories(limit=50)['categories']['items']]

# %% [markdown]
# oh noooo! categories seem to be different everytime we query the API

# %%
lst1 = [item['id'] for item in sp.categories(limit=50)['categories']['items']]

# %%
lst2 = [item['id'] for item in sp.categories(limit=50)['categories']['items']]

# %%
set(lst1) == set(lst2)

# %% [markdown]
# ## Karina's

# %% [markdown]
# Playlist link: https://open.spotify.com/playlist/4BQE8UGPzqnsyStbdic96g </br>
#
# from that ID : 5c1883b103534b7bb0057960a379e142

# %%
playlist_ka = sp.user_playlist_tracks('karinac', '4BQE8UGPzqnsyStbdic96g')

# playlist id: in url after playlist/ and before ?

# https://open.spotify.com/playlist/4BQE8UGPzqnsyStbdic96g

# %%
len(playlist_ka['items'])
# Out:
# 4

# %%
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1EFkoyFGsSJb30/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '1970-01-01T00:00:00Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5UUG83KSlqPhrBssrducWV'},
#        'href': 'https://api.spotify.com/v1/artists/5UUG83KSlqPhrBssrducWV',
#        'id': '5UUG83KSlqPhrBssrducWV',
#        'name': 'Spotify',
#        'type': 'artist',
#        'uri': 'spotify:artist:5UUG83KSlqPhrBssrducWV'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
# ...

# %%
# Out:
# 42

# %% [markdown]
# Overall goal of this part of gnod is **a dataframe**

# %% [markdown]
# ### Target: Get all the ID's for all the songs in that playlist

# %%
# ID for only one song
playlist['items'][0]['track']['id']

# make it work in the whole playlist
for item in playlist['items']:
    print(item['track']['id'])
    
karinac = []
for item in playlist['items']:
    karinac.append(item['track']['id'])

# %%
karinac
# Out:
# --------------------------------------------------------------------------
# NameError                                Traceback (most recent call last)
# <ipython-input-19-18e4326e9901> in <module>
# ----> 1 karinac
#
# NameError: name 'karinac' is not defined

# %%
#the audio features for all songs in the playlist
sp.audio_features(tracks=karinac)

# %%
audio_features_nigeria = pd.Dataframe(sp.audio_features(tracks=karinac))

# %%
audio_features_karinac.head()

# %% [markdown]
# ## For the Project

# %%
from data_gathering_tolls import get_spotufy_data, get_top100_data
spotify_df = get.spotify_data()
# Out:
# --------------------------------------------------------------------------
# ModuleNotFoundError                      Traceback (most recent call last)
# <ipython-input-14-d5065d0a4455> in <module>
# ----> 1 from data_gathering_tolls import get_spotufy_data, get_top100_data
#       2 spotify_df = get.spotify_data()
#
# ModuleNotFoundError: No module named 'data_gathering_tolls'
