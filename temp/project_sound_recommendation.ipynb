# %% [markdown]
# # Project Sound Recommendation

# %% [markdown]
# based on a playlist (as the input of the user)

# %%
# import necessary spotipy tools
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import getpass
import pandas as pd

# %%
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=client_id,
                                                          client_secret=client_secret))

sp

# %%
playlist = sp.user_playlist_tracks("bowliekids", "57kLqxcEBVDlL0sMBVtCmN")

# https://open.spotify.com/playlist/57kLqxcEBVDlL0sMBVtCmN?si=32cbf0d2b12a4fc0&nd=1

# %%
len(playlist['items'])
# Out:
# 24

# %%
# input a song

# %%
song = str(input("what is the song?: "))
# Out:
# what is the song?: Bohemian Rapisody

# %%
# Bohemian Rapisody
song = {song}

# %%
results = sp.search(q=song, limit=50)
results
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Bohemian+Rapisody&type=track&offset=0&limit=50',
#   'items': [{'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
# ...

# %%
# my_track = results['tracks']['items'][0]
# my_track

# %%
# result['tracks']['items'][0]['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4M1FpEWs2PeYfJe7xxJfhH'},
#   'href': 'https://api.spotify.com/v1/artists/4M1FpEWs2PeYfJe7xxJfhH',
#   'id': '4M1FpEWs2PeYfJe7xxJfhH',
#   'name': 'Freddie Mercury',
#   'type': 'artist',
#   'uri': 'spotify:artist:4M1FpEWs2PeYfJe7xxJfhH'}]

# %%
# artist_uri = 'spotify:artist:2WX2uTcsvV5OnS0inACecP'

# %%
uri = result['tracks']['items'][0]['uri']

# %%
uri
# Out:
# 'spotify:track:7m1JSCGnmorA3tjtWJpDj4'

# %%
# these are the audio features for all songs in the playlist
sp.audio_features(tracks=results)
# Out:
# [None]

# %%
# Get all the ID's for all the songs in that playlist!
# let's get the ID for only one song first!
print(playlist['items'][0]['track']['id'])
# Out:
# 0wXuerDYiBnERgIpbb3JBR

# %%
# here i make it work for the whole playlist
for item in playlist['items']:
    print(item['track']['id'])
# Out:
# 0wXuerDYiBnERgIpbb3JBR
# 5iUQMwxUPdJBFeGkePtM66
# 4vHNeBWDQpVCmGbaccrRzi
# 7lT1dCz96jANsLAAADlfIg
# 36rqjSUBaArtMBLWrzwInc
# 37y7iDayfwm3WXn5BiAoRk
# 5NhlpQ6BOIz3S5welptk1W
# 2ZIHKdsXfOS3cZoGRD2vGL
# 0eEXcw3JLVXcRxYrVYMy68
# 4uQ7wYsuL0DryknoDc11Hk
# 2N4idqj9TT3HnH2OFT9j0v
# 2X485T9Z5Ly0xyaghN73ed
# 6h5IlvRJ2ZNPloCOdzUmyW
# 1RRBuxXdsIB0yazqGDlKTj
# 3NRql0A1Ef4RCvT473iqgD
# 5dvpipXxOIH96gcGEKR1Iu
# 4keAoywVf4jxRvXU7ON0hV
# 7CH99b2i1TXS5P8UUyWtnM
# 3Ti0GdlrotgwsAVBBugv0I
# 4GdB5M7GbwLZLouktYocFC
# 6fkL9CjWmjeV6vfDxTp9OZ
# 1QqJP4E1i6EaocGqa9jxIn
# 3Wdwnr9TGwmyUfPNB9iekU
# 01TyFEZu6mHbffsVfxgrFn

# %%
bowliekids = []
for item in playlist['items']:
    bowliekids.append(item['track']['id'])

# %%
# these are the audio features for all songs in the playlist
sp.audio_features(tracks=bowliekids)
# Out:
# [{'danceability': 0.743,
#   'energy': 0.347,
#   'key': 1,
#   'loudness': -11.174,
#   'mode': 1,
#   'speechiness': 0.121,
#   'acousticness': 0.167,
#   'instrumentalness': 0.00951,
#   'liveness': 0.103,
#   'valence': 0.572,
#   'tempo': 160.143,
#   'type': 'audio_features',
#   'id': '0wXuerDYiBnERgIpbb3JBR',
#   'uri': 'spotify:track:0wXuerDYiBnERgIpbb3JBR',
#   'track_href': 'https://api.spotify.com/v1/tracks/0wXuerDYiBnERgIpbb3JBR',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0wXuerDYiBnERgIpbb3JBR',
#   'duration_ms': 326933,
#   'time_signature': 4},
#  {'danceability': 0.836,
#   'energy': 0.67,
#   'key': 5,
#   'loudness': -6.907,
#   'mode': 0,
#   'speechiness': 0.23,
#   'acousticness': 0.00826,
#   'instrumentalness': 0.000355,
#   'liveness': 0.0837,
#   'valence': 0.556,
#   'tempo': 107.018,
#   'type': 'audio_features',
#   'id': '5iUQMwxUPdJBFeGkePtM66',
#   'uri': 'spotify:track:5iUQMwxUPdJBFeGkePtM66',
# ...

# %%
audio_features_bowliekids = pd.DataFrame(sp.audio_features(tracks=bowliekids))
audio_features_bowliekids.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.743   0.347    1   -11.174     1       0.1210       0.16700
# 1         0.836   0.670    5    -6.907     0       0.2300       0.00826
# 2         0.739   0.522    7   -12.304     0       0.1510       0.82100
# 3         0.856   0.841    6    -7.737     0       0.3350       0.09770
# 4         0.573   0.473    8   -10.839     0       0.0268       0.09440
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0          0.009510    0.1030    0.572  160.143  audio_features
# 1          0.000355    0.0837    0.556  107.018  audio_features
# 2          0.001240    0.2330    0.619  138.263  audio_features
# 3          0.000000    0.0773    0.794   95.418  audio_features
# 4          0.397000    0.1990    0.515   77.494  audio_features
#
#                        id                                   uri  \
# 0  0wXuerDYiBnERgIpbb3JBR  spotify:track:0wXuerDYiBnERgIpbb3JBR
# ...

# %% [markdown]
# ## spotify categories

# %%
# get the spotify categories
sp.categories(limit=50)
# Out:
# {'categories': {'href': 'https://api.spotify.com/v1/browse/categories?offset=0&limit=50',
#   'items': [{'href': 'https://api.spotify.com/v1/browse/categories/toplists',
#     'icons': [{'height': 275,
#       'url': 'https://t.scdn.co/media/derived/toplists_11160599e6a04ac5d6f2757f5511778f_0_0_275_275.jpg',
#       'width': 275}],
#     'id': 'toplists',
#     'name': 'Top Lists'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/at_home',
#     'icons': [{'height': None,
#       'url': 'https://t.scdn.co/images/04da469dd7be4dab96659aa1fa9f0ac9.jpeg',
#       'width': None}],
#     'id': 'at_home',
#     'name': 'At Home'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/equal',
#     'icons': [{'height': None,
#       'url': 'https://t.scdn.co/images/084155aeaa724ea1bd393a017d67b709',
#       'width': None}],
#     'id': 'equal',
#     'name': 'EQUAL'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/mood',
#     'icons': [{'height': 274,
# ...

# %%
# get all the id's for all the categories
[item['id'] for item in sp.categories(limit=50)['categories']['items']]
# Out:
# ['toplists',
#  'at_home',
#  'equal',
#  'mood',
#  'radar',
#  'wellness',
#  'pop',
#  'hiphop',
#  'edm_dance',
#  'indie_alt',
#  'alternative',
#  'rock',
#  'classical',
#  'jazz',
#  'rnb',
#  'soul',
#  'funk',
#  'roots',
#  'country',
#  'blues',
#  'latin',
#  'kpop',
#  'metal',
#  'punk',
#  'instrumental',
#  'kids_family',
#  'student',
#  'popculture',
#  'decades',
#  'party',
#  'pride',
#  'gaming',
#  'workout',
#  'summer',
#  'chill',
#  'romance',
#  'dinner',
#  'focus',
#  'sleep',
#  'in_the_car',
#  'travel',
#  'thirdparty',
#  'afro',
#  'caribbean',
#  'arab',
#  'desi',
#  'audiobooks']

# %% [markdown]
# categories changes all the time

# %%
lst1 = [item['id'] for item in sp.categories(limit=50)['categories']['items']]

# %%
lst2 = [item['id'] for item in sp.categories(limit=50)['categories']['items']]

# %%
set(lst1)==set(lst2)
# Out:
# False

# %%
## Get the artists and their musics

# %%
results = sp.search(q="Lady Gaga", limit=50)
results
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Lady+Gaga&type=track&offset=0&limit=50',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#        'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#        'id': '1HY2Jd0NmPuamShAr6KMms',
#        'name': 'Lady Gaga',
#        'type': 'artist',
#        'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
# ...

# %%
my_track = results['tracks']['items'][0]

# %%
my_track
# Out:
# {'album': {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#     'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#     'id': '1HY2Jd0NmPuamShAr6KMms',
#     'name': 'Lady Gaga',
#     'type': 'artist',
#     'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BZ',
#    'CA',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
# ...

# %%
my_track['artists']=results['tracks']['items'][0]

# %%
results = sp.search(q="Lady Gaga", limit=50)

# %%
results
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Lady+Gaga&type=track&offset=0&limit=50',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#        'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#        'id': '1HY2Jd0NmPuamShAr6KMms',
#        'name': 'Lady Gaga',
#        'type': 'artist',
#        'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
# ...

# %%
def get_artists_from_track(track):
    return [artist["name"] for artist in track["artists"]]

def get_artists_ids_from_track(track):
    return [artist["id"] for artist in track["artists"]]

# %%
# get artist ID
get_artists_ids_from_track(results["tracks"]["items"][0])
# Out:
# ['1HY2Jd0NmPuamShAr6KMms']
