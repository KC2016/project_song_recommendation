# %%
# import necessary spotipy tools
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import getpass
import pandas as pd

# %%
# connect to the API
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id="    ",
                                                           client_secret="        "))

# %%
playlist = sp.user_playlist_tracks("bowliekids", "57kLqxcEBVDlL0sMBVtCmN")

# %%
len(playlist['items'])
# Out:
# 24

# %%
# let's get the ID for only one song first!
playlist['items'][0]['track']['id']

# here i make it work for the whole playlist
for item in playlist['items']:
    print(item['track']['id'])

CookingWithDK = []
for item in playlist['items']:
    CookingWithDK.append(item['track']['id'])
# Out:
# 0wXuerDYiBnERgIpbb3JBR
# 5iUQMwxUPdJBFeGkePtM66
# 4vHNeBWDQpVCmGbaccrRzi
# 7lT1dCz96jANsLAAADlfIg
# 36rqjSUBaArtMBLWrzwInc
# 37y7iDayfwm3WXn5BiAoRk
# 5NhlpQ6BOIz3S5welptk1W
# 2ZIHKdsXfOS3cZoGRD2vGL
# 0eEXcw3JLVXcRxYrVYMy68
# 4uQ7wYsuL0DryknoDc11Hk
# 2N4idqj9TT3HnH2OFT9j0v
# 2X485T9Z5Ly0xyaghN73ed
# 6h5IlvRJ2ZNPloCOdzUmyW
# 1RRBuxXdsIB0yazqGDlKTj
# 3NRql0A1Ef4RCvT473iqgD
# 5dvpipXxOIH96gcGEKR1Iu
# 4keAoywVf4jxRvXU7ON0hV
# 7CH99b2i1TXS5P8UUyWtnM
# 3Ti0GdlrotgwsAVBBugv0I
# 4GdB5M7GbwLZLouktYocFC
# 6fkL9CjWmjeV6vfDxTp9OZ
# 1QqJP4E1i6EaocGqa9jxIn
# 3Wdwnr9TGwmyUfPNB9iekU
# 01TyFEZu6mHbffsVfxgrFn

# %%
# these are the audio features for all songs in the playlist
sp.audio_features(tracks=CookingWithDK)
# Out:
# [{'danceability': 0.743,
#   'energy': 0.347,
#   'key': 1,
#   'loudness': -11.174,
#   'mode': 1,
#   'speechiness': 0.121,
#   'acousticness': 0.167,
#   'instrumentalness': 0.00951,
#   'liveness': 0.103,
#   'valence': 0.572,
#   'tempo': 160.143,
#   'type': 'audio_features',
#   'id': '0wXuerDYiBnERgIpbb3JBR',
#   'uri': 'spotify:track:0wXuerDYiBnERgIpbb3JBR',
#   'track_href': 'https://api.spotify.com/v1/tracks/0wXuerDYiBnERgIpbb3JBR',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0wXuerDYiBnERgIpbb3JBR',
#   'duration_ms': 326933,
#   'time_signature': 4},
#  {'danceability': 0.836,
#   'energy': 0.67,
#   'key': 5,
#   'loudness': -6.907,
#   'mode': 0,
#   'speechiness': 0.23,
#   'acousticness': 0.00826,
#   'instrumentalness': 0.000355,
#   'liveness': 0.0837,
#   'valence': 0.556,
#   'tempo': 107.018,
#   'type': 'audio_features',
#   'id': '5iUQMwxUPdJBFeGkePtM66',
#   'uri': 'spotify:track:5iUQMwxUPdJBFeGkePtM66',
# ...

# %%
audio_features_DK = pd.DataFrame(sp.audio_features(tracks=CookingWithDK))

# %%
audio_features_DK.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.743   0.347    1   -11.174     1       0.1210       0.16700
# 1         0.836   0.670    5    -6.907     0       0.2300       0.00826
# 2         0.739   0.522    7   -12.304     0       0.1510       0.82100
# 3         0.856   0.841    6    -7.737     0       0.3350       0.09770
# 4         0.573   0.473    8   -10.839     0       0.0268       0.09440
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0          0.009510    0.1030    0.572  160.143  audio_features
# 1          0.000355    0.0837    0.556  107.018  audio_features
# 2          0.001240    0.2330    0.619  138.263  audio_features
# 3          0.000000    0.0773    0.794   95.418  audio_features
# 4          0.397000    0.1990    0.515   77.494  audio_features
#
#                        id                                   uri  \
# 0  0wXuerDYiBnERgIpbb3JBR  spotify:track:0wXuerDYiBnERgIpbb3JBR
# ...

# %%
audio_features_DK
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.743   0.347    1   -11.174     1       0.1210       0.16700
# 1          0.836   0.670    5    -6.907     0       0.2300       0.00826
# 2          0.739   0.522    7   -12.304     0       0.1510       0.82100
# 3          0.856   0.841    6    -7.737     0       0.3350       0.09770
# 4          0.573   0.473    8   -10.839     0       0.0268       0.09440
# 5          0.603   0.783    6    -4.023     1       0.0620       0.44900
# 6          0.707   0.562    0    -7.621     1       0.0305       0.12400
# 7          0.698   0.514    0   -10.325     1       0.0663       0.14800
# 8          0.866   0.534   11    -9.201     1       0.2290       0.18400
# 9          0.925   0.549    7    -6.572     1       0.0656       0.39600
# 10         0.709   0.496    1   -10.528     0       0.0417       0.58100
# 11         0.602   0.881    1    -5.875     0       0.0443       0.00462
# ...

# %%
sp.categories(limit=50)
# Out:
# {'categories': {'href': 'https://api.spotify.com/v1/browse/categories?offset=0&limit=50',
#   'items': [{'href': 'https://api.spotify.com/v1/browse/categories/toplists',
#     'icons': [{'height': 275,
#       'url': 'https://t.scdn.co/media/derived/toplists_11160599e6a04ac5d6f2757f5511778f_0_0_275_275.jpg',
#       'width': 275}],
#     'id': 'toplists',
#     'name': 'Top Lists'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/at_home',
#     'icons': [{'height': None,
#       'url': 'https://t.scdn.co/images/04da469dd7be4dab96659aa1fa9f0ac9.jpeg',
#       'width': None}],
#     'id': 'at_home',
#     'name': 'At Home'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/equal',
#     'icons': [{'height': None,
#       'url': 'https://t.scdn.co/images/084155aeaa724ea1bd393a017d67b709',
#       'width': None}],
#     'id': 'equal',
#     'name': 'EQUAL'},
#    {'href': 'https://api.spotify.com/v1/browse/categories/mood',
#     'icons': [{'height': 274,
# ...

# %%
ids = []

for category in ['categories']['items']:
    ids.append(category['id'])
# Out:
# <>:3: SyntaxWarning: list indices must be integers or slices, not str; perhaps you missed a comma?
# <>:3: SyntaxWarning: list indices must be integers or slices, not str; perhaps you missed a comma?
# <ipython-input-15-aaca9754193d>:3: SyntaxWarning: list indices must be integers or slices, not str; perhaps you missed a comma?
#   for category in ['categories']['items']:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-aaca9754193d> in <module>
#       1 ids = []
#       2
# ----> 3 for category in ['categories']['items']:
#       4     ids.append(category['id'])
#
# TypeError: list indices must be integers or slices, not str

# %%
for x in cat_ids:
    print(x, len([item['id'] for item in sp.category_playlists(category_id=x)['playlists']['items']]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-d6941a8a64f3> in <module>
# ----> 1 for x in cat_ids:
#       2     print(x, len([item['id'] for item in sp.category_playlists(category_id=x)['playlists']['items']]))
#
# NameError: name 'cat_ids' is not defined

# %%
[item['id'] for item in sp.categories(limit=50)['categories']['items']]
# Out:
# ['toplists',
#  'at_home',
#  'equal',
#  'mood',
#  'radar',
#  'wellness',
#  'pop',
#  'hiphop',
#  'edm_dance',
#  'indie_alt',
#  'alternative',
#  'rock',
#  'classical',
#  'jazz',
#  'rnb',
#  'soul',
#  'funk',
#  'roots',
#  'country',
#  'blues',
#  'latin',
#  'kpop',
#  'metal',
#  'punk',
#  'instrumental',
#  'kids_family',
#  'student',
#  'popculture',
#  'decades',
#  'party',
#  'pride',
#  'gaming',
#  'workout',
#  'summer',
#  'chill',
#  'romance',
#  'dinner',
#  'focus',
#  'sleep',
#  'in_the_car',
#  'travel',
#  'thirdparty',
#  'afro',
#  'caribbean',
#  'arab',
#  'desi',
#  'audiobooks']

# %%
playlist2 = sp.user_playlist_tracks("Christopher Cobb", "7FW7aWJS6Ty6gNwt0TYrGX")


#playlist2 = 'https://open.spotify.com/playlist/7FW7aWJS6Ty6gNwt0TYrGX?si=10548ffc2a81435b'

# %%
len(playlist2['items'])
# Out:
# 100

# %%
playlist2['items'].keys()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-50-eb8cd9300355> in <module>
# ----> 1 playlist2['items'].keys()
#
# AttributeError: 'list' object has no attribute 'keys'

# %%
artist_name = []
track_name = []
popularity = []
track_id = []
for i in range(0,1000,50):
    track_results = sp.search(q='year:2021', type='track', limit=50,offset=i)
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        track_name.append(t['name'])
        track_id.append(t['id'])
        popularity.append(t['popularity'])

# %%
artist_name2 = []
track_name2 = []
popularity2 = []
track_id2 = []
for i in range(0,1000,50):
    track_results2 = sp.search(q='year:2020', type='track', limit=50,offset=i)
    for i, t in enumerate(track_results2['tracks']['items']):
        artist_name2.append(t['artists'][0]['name'])
        track_name2.append(t['name'])
        track_id2.append(t['id'])
        popularity2.append(t['popularity'])

# %%
track_dataframe2 = pd.DataFrame({'artist_name' : artist_name, 'track_name' : track_name, 'track_id' : track_id, 'popularity' : popularity})
print(track_dataframe2.shape)
track_dataframe2.head()
# Out:
# (1000, 4)
#       artist_name                                         track_name  \
# 0          Polo G                                            RAPSTAR
# 1  Banc Champagne                                      New Year 2021
# 2   Justin Bieber             Peaches (feat. Daniel Caesar & Giveon)
# 3              U2  New Year's Day - Live From Red Rocks Amphithea...
# 4        Doja Cat                           Kiss Me More (feat. SZA)
#
#                  track_id  popularity
# 0  43PGPuHIlVOc04jrZVh9L6          95
# 1  0QdTYExlsPJxj1lkPVwNMg          18
# 2  4iJyoBOLtHqaGxP12qzhQI         100
# 3  6tBQZFVP2nvhUfc6gMQjF0          38
# 4  748mdHapucXQri7IAO8yFK          95

# %%
track_dataframe.columns = ['artist', 'track', 'track_id', 'popularity']

# %%
track_dataframe2.columns = ['artist', 'track', 'track_id', 'popularity']

# %%
Diddy = CookingWithDK.append(track_dataframe, ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-1b776985683a> in <module>
# ----> 1 Diddy = CookingWithDK.append(track_dataframe, ignore_index=True)
#
# TypeError: append() takes no keyword arguments

# %%
def HotBox():
    from random import randint
    #input from user
    song_choice=input("Pick a song")
    if len(song_choice)==0:
        print("it looks like you can't think of a song at the moment")
    else: 
        song_choice_l=song_choice.lower() #convert input to lowercase
        filter_song=track_dataframe[(track_dataframe["track"].str.lower()).str.contains(song_choice_l)]# convert target to lowercase
        #check if its in the list we have
        if len(filter_song) ==0:
            print("Poor choice")

        else:
            # if song is in billboard hot 100, confirm it, recommend another random hot song
            print("Now that's a hit")
            random_song = randint(0, len(track_dataframe)-1)
            print("You might also like '" + track_dataframe["track"][random_song] + "' by " + track_dataframe["artist"][random_song])

# %%
HotBox()
# Out:
# Pick a song
# Now that's a hit
# You might also like 'Sultry Ambiance for 2021' by Cafe BGM

# %%
playlists = pd.read_csv("607ids.csv")

# %%
playlists.head()
# Out:
#    Unnamed: 0                playlist
# 0           0  37i9dQZF1DWUFmyho2wkQU
# 1           1  37i9dQZF1DZ06evO1Xa1Op
# 2           2  37i9dQZF1DXcbGhAooTSJy
# 3           3  37i9dQZF1DWZMWLrh2UzwC
# 4           4  37i9dQZF1DX6uhsAfngvaD

# %%
biglist = playlists['playlist'].tolist()

# %%
biglist
# Out:
# ['37i9dQZF1DWUFmyho2wkQU',
#  '37i9dQZF1DZ06evO1Xa1Op',
#  '37i9dQZF1DXcbGhAooTSJy',
#  '37i9dQZF1DWZMWLrh2UzwC',
#  '37i9dQZF1DX6uhsAfngvaD',
#  '37i9dQZF1DWYmmr74INQlb',
#  '37i9dQZF1DWZqUHC2tviPw',
#  '37i9dQZF1DXbgLhPxSBEKX',
#  '37i9dQZF1DWYRTlrhMB12D',
#  '37i9dQZF1DWTJ7xPn4vNaz',
#  '37i9dQZF1DX5Ejj0EkURtP',
#  '37i9dQZF1DX50QitC6Oqtn',
#  '37i9dQZF1DWXbttAJcbphz',
#  '37i9dQZF1DX8SE5tIsUWTD',
#  '37i9dQZF1DX7HGyCQ2dcNx',
#  '37i9dQZF1DX4qKWGR9z0LI',
#  '37i9dQZF1DX0z1epx5KTtS',
#  '37i9dQZF1DX9udeSemCofA',
#  '37i9dQZF1DWU0ScTcjJBdj',
#  '37i9dQZF1DX2E5psOxzjXz',
#  '37i9dQZF1DX4WgZiuR77Ef',
#  '37i9dQZF1DX2zAr9vdmFlU',
#  '37i9dQZF1DWXnscMH24yOc',
#  '37i9dQZF1DX8RXxAW8DgJV',
#  '37i9dQZF1DWUptwB9dhZvQ',
#  '37i9dQZF1DXdx7sCF75xKy',
#  '37i9dQZF1DWWnpcjfCqaW0',
#  '37i9dQZF1DXbn7xTVabEKT',
#  '37i9dQZF1DX8FwnYE6PRvL',
#  '37i9dQZF1DWYTn3LtYLd3y',
#  '37i9dQZF1DWZhxU4AiByxO',
#  '37i9dQZF1DWZeKCadgRdKQ',
#  '37i9dQZF1DWWi0hHcPHnic',
#  '37i9dQZF1DWYAyGN1XM1YS',
# ...

# %%
some_playlists = biglist[:10]

# %%
some_playlists
# Out:
# ['37i9dQZF1DWUFmyho2wkQU',
#  '37i9dQZF1DZ06evO1Xa1Op',
#  '37i9dQZF1DXcbGhAooTSJy',
#  '37i9dQZF1DWZMWLrh2UzwC',
#  '37i9dQZF1DX6uhsAfngvaD',
#  '37i9dQZF1DWYmmr74INQlb',
#  '37i9dQZF1DWZqUHC2tviPw',
#  '37i9dQZF1DXbgLhPxSBEKX',
#  '37i9dQZF1DWYRTlrhMB12D',
#  '37i9dQZF1DWTJ7xPn4vNaz']

# %%
some_list = sp.user_playlist_tracks("patrickimoh", "37i9dQZF1DWUFmyho2wkQU")

# %%
for item in some_list['items']:
    print(item['track']['id'])
# Out:
# 03tqyYWC9Um2ZqU0ZN849H
# 1wLhwzPAtze5JT8qqXlqaO
# 1BKT2I9x4RGKaKqW4up34s
# 4ns1XFP3W5JPyzvnAjMdHD
# 1bTphHXspys3RvvRxfzzIc
# 3cSuhzV7wKX5diQ8hos78P
# 1GxHeBvQ9935Dd3cSfsfBa
# 0Ss50OU9tCozI7JIywkv14
# 7cFpB4ozcSwXuhqjvNbrbP
# 59rtiYOPgMEDf3yPEfU2la
# 2aIdVb8v9KTpEZnftkz2mD
# 41PWz0hAiU9FqsmjR9Wh62
# 41bIQPBE1lFN0mmw6Lmssz
# 2cYZpcIV39X48RnOFM7w2V
# 0r2Bul2NuCViraT2zX1l5j
# 2e9EZ2V5QGGZPMJacO3y0Y
# 6ScJMrlpiLfZUGtWp4QIVt
# 5MYFw4T2gy52pOGBN4EYHS
# 2hzKxuc2LwqMnkoVRMkV0B
# 5dANgSy7v091dhiPnEXNrf
# 3LN41NUdHkyNqQhi9gExMm
# 69bHJ9qs5FrUJbKP8xU8uZ
# 5hOrYYtUd96bIOBjuSEArP
# 3ssX20QT5c3nA9wk78V1LQ
# 0bdabO15YOj0iZPg2OujAw
# 6lEIjrQNwJPecJ7mMXjhjo
# 25YwwruYRtxe6RQdKtrZFS
# 68IM0wOuxlrbwk0zgmi9dk
# 0hmQY8NW6hNQWfkvZsa1e9
# 2tOZtdbkAMQASWokLvSlzj
# 3rMyMv8EjKXoPnaRo2hdJN
# 6Wt5QBzHp9vdSLAFlvdnDQ
# 5VkuqayHiiU5ZHyYEH4Oeb
# 6BdgtqiV3oXNqBikezwdvC
# 39yRhjDdSTP4A7VehxBXDb
# 0YUrjFy4qFKOO5NhM9tYdV
# 5krOROgmf8adn3SJzeKLZy
# 0F7rEdewJ6cSLylOZZpDu7
# 57kdeoYzgGaKzRWj4XM1u8
# 4s0o8TJHfX9LLHa0umnOzT
# ...

# %%
# trying this: https://github.com/MaxHilsdorf/introduction_to_spotipy/blob/master/introduction_to_spotipy.ipynb

# %%
playlist_creator = "Sam"
playlist_id = "7FW7aWJS6Ty6gNwt0TYrGX"

# %%
def analyze_playlist(creator, playlist_id):
    
    # Create empty dataframe
    playlist_features_list = ["artist", "album", "track_name", "track_id", 
                             "danceability", "energy", "key", "loudness", "mode", "speechiness",
                             "instrumentalness", "liveness", "valence", "tempo", "duration_ms", "time_signature"]
    playlist_df = pd.DataFrame(columns = playlist_features_list)
    
    # Create empty dict
    playlist_features = {}
    
    # Loop through every track in the playlist, extract features and append the features to the playlist df
    playlist = sp.user_playlist_tracks(creator, playlist_id)["items"]
    for track in playlist:
        # Get metadata
        playlist_features["artist"] = track["track"]["album"]["artists"][0]["name"]
        playlist_features["album"] = track["track"]["album"]["name"]
        playlist_features["track_name"] = track["track"]["name"]
        playlist_features["track_id"] = track["track"]["id"]
        # Get audio features
        audio_features = sp.audio_features(playlist_features["track_id"])[0]
        for feature in playlist_features_list[4:]:
            playlist_features[feature] = audio_features[feature]
        
        # Concat the dfs
        track_df = pd.DataFrame(playlist_features, index = [0])
        playlist_df = pd.concat([playlist_df, track_df], ignore_index = True)
        
    return playlist_df

# %%
playlist_df = analyze_playlist(playlist_creator, playlist_id)

# %%
playlist_df.head()
# Out:
#            artist                        album                   track_name  \
# 0      McFabulous  I Live Above the Hobby Shop  I Live Above the Hobby Shop
# 1  Arthur Russell       Calling Out Of Context   That's Us/Wild Combination
# 2     Daniel Hart              The Orientalist                   O Sangeeta
# 3  Future Of What                   Pro Dreams              Double Thoughts
# 4           Kings          October/I Got Stuck                      October
#
#                  track_id  danceability  energy key  loudness mode  \
# 0  0vvfvOnFtAXhStLPmZWxhV         0.838   0.430   1   -10.123    1
# 1  0WD900RjyjBcxtGu3baTAb         0.660   0.406   1   -13.341    0
# 2  48qe2ZBFaOgezPnuEKvOL8         0.724   0.480   0    -4.815    1
# 3  5Oln1rKfDShAwEeLyFQ4DB         0.554   0.411   4    -9.114    1
# 4  2iZFN0NfgKRqyUttQQS9Ga         0.319   0.174   0   -10.799    1
#
#    speechiness  instrumentalness  liveness  valence    tempo duration_ms  \
# ...

# %%
def analyze_playlist(creator, playlist_id):
# Create empty dataframe
playlist_features_list = ["artist","album","track_name", "track_id","danceability","energy","key","loudness","mode", "speechiness", "instrumentalness","liveness","valence","tempo", "duration_ms","time_signature"]
playlist_df = pd.DataFrame(columns = playlist_features_list)
# Loop through every track in the playlist, extract features and append the features to the playlist df
# playlist = sp.user_playlist_tracks(creator, playlist_id)["items"]
results = sp.user_playlist_tracks(creator, playlist_id)
playlist = results['items']
while results['next']:
results = sp.next(results)
playlist.extend(results['items'])
for track in playlist:
if track["track"] is None:
continue
else:
# Create empty dict
playlist_features = {}
# Get metadata
playlist_features["artist"] = track["track"]["album"]["artists"][0]["name"]
playlist_features["album"] = track["track"]["album"]["name"]
playlist_features["track_name"] = track["track"]["name"]
playlist_features["track_id"] = track["track"]["id"]
# Get audio features
audio_features = sp.audio_features(playlist_features["track_id"])[0]
if audio_features is None:
continue
else:
for feature in playlist_features_list[4:]:
playlist_features[feature] = audio_features[feature]
# Concat the dfs
track_df = pd.DataFrame(playlist_features, index = [0])
playlist_df = pd.concat([playlist_df, track_df], ignore_index = True)
return playlist_df
# Out:
#   File "<ipython-input-83-28d216c51ead>", line 3
#     playlist_features_list = ["artist","album","track_name", "track_id","danceability","energy","key","loudness","mode", "speechiness", "instrumentalness","liveness","valence","tempo", "duration_ms","time_signature"]
#     ^
# IndentationError: expected an indented block

# %%
#trying to scrape multiple playlists. Have to add playlist name and name of creator but i dont know either. made them up

# %%
playlist_dict2 = {
    
    "playlist1" : ('sam','37i9dQZF1DWUFmyho2wkQU'),
 "playlist2" : ('sam','37i9dQZF1DZ06evO1Xa1Op'),
  "playlist3" : ('sam','37i9dQZF1DXcbGhAooTSJy'),
  "playlist4" : ('sam','37i9dQZF1DWZMWLrh2UzwC'),
  "playlist5" : ('sam','37i9dQZF1DX6uhsAfngvaD'),
  "playlist6" : ('sam','37i9dQZF1DWYmmr74INQlb'),
  "playlist7" : ('sam','37i9dQZF1DWZqUHC2tviPw'),
  "playlist8" : ('sam','37i9dQZF1DXbgLhPxSBEKX'),
  "playlist9" : ('sam','37i9dQZF1DWYRTlrhMB12D'),
  "playlist10" : ('sam','37i9dQZF1DWTJ7xPn4vNaz')
    
    
}

# %%
playlist_dict = {
    
    "playlist1" : ('sam','37i9dQZF1DWUFmyho2wkQU'),
 "playlist2" : ('sam','37i9dQZF1DZ06evO1Xa1Op'),
    "playlist7" : ('sam','37i9dQZF1DWZqUHC2tviPw'),
  "playlist8" : ('sam','37i9dQZF1DXbgLhPxSBEKX'),
  "playlist9" : ('sam','37i9dQZF1DWYRTlrhMB12D'),
  "playlist10" : ('sam','37i9dQZF1DWTJ7xPn4vNaz'),
"Cooking with DK" : ('Dionne', '57kLqxcEBVDlL0sMBVtCmN')


}

# %%
def analyze_playlist_dict(playlist_dict):
    
    # Loop through every playlist in the dict and analyze it
    for i, (key, val) in enumerate(playlist_dict.items()):
        playlist_df = analyze_playlist(*val)
        # Add a playlist column so that we can see which playlist a track belongs too
        playlist_df["playlist"] = key
        # Create or concat df
        if i == 0:
            playlist_dict_df = playlist_df
        else:
            playlist_dict_df = pd.concat([playlist_dict_df, playlist_df], ignore_index = True)
            
    return playlist_dict_df

# %%
multiple_playlist_df = analyze_playlist_dict(playlist_dict)

# %%
multiple_playlist_df.loc[multiple_playlist_df['playlist'] == "Cooking with DK"]
# Out:
#                    artist                                              album  \
# 444      Childish Gambino                                 "Awaken, My Love!"
# 445            Mac Miller                                The Divine Feminine
# 446           Still Woozy                                         Goodie Bag
# 447               MF DOOM                     Operation: Doomsday (Complete)
# 448           Mac DeMarco                                       This Old Dog
# 449            Steve Lacy                                           Dark Red
# 450      Childish Gambino                                              Kauai
# 451            Thundercat                                              Drunk
# 452  A Tribe Called Quest                                      The Anthology
# 453         Vince Staples                                     Summertime '06
# 454           Mac DeMarco                                       This Old Dog
# ...

# %%
multiple_playlist_df
# Out:
#                            artist                      album  \
# 0               Waka Flocka Flame                 Flockaveli
# 1                     Trick Daddy               THUGS ARE US
# 2                             DMX  It's Dark And Hell Is Hot
# 3                             UGK    UGK (Underground Kingz)
# 4    Lil Jon & The East Side Boyz                Crunk Juice
# ..                            ...                        ...
# 463                       Outkast                   Aquemini
# 464                    Thundercat                      Drunk
# 465                    Thundercat                      Drunk
# 466                        Sampha                    Process
# 467                   Men I Trust                Show Me How
#
#                                             track_name  \
# 0                  No Hands (feat. Roscoe Dash & Wale)
# 1                                  Take It to da House
# 2                                  Ruff Ryders' Anthem
# ...
